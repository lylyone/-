# %% [markdown]
# # KNN - k近邻算法
# k-Nearest Neighbors
#
# 如果一个样本在特征空间中的k个最相似(即特征空间中最邻近)的样本中的大多数属于某一个类别，则该样本也属于这个类别。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #KNN 简单实现

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#原始集合
#特征
raw_data_x=[
             [3.393533211,2.331273381],
             [2.110073483,1.781539638],
             [1.343808831,3.368360954],
             [3.582294042,4.679179110],
             [2.280362439,2.866990263],
             [7.423436942,4.696522875],
             [5.745051997,3.533989803],
             [9.172168622,2.511101045],
             [7.792783481,3.424088941],
             [7.939820817,0.791637231]
]

# %%
#所属类别
raw_data_y = [0,0,0,0,0,1,1,1,1,2]

# %%
#训练集合 将列表转换成数组
X_train=np.array(raw_data_x)
y_train=np.array(raw_data_y)

#要预测的点
x = np.array([8.093607318,3.365731514])

# %%
X_train.shape
# Out:
# (10, 2)

# %%
X_train.shape[0]
# Out:
# 10

# %%
X_train.shape[1]
# Out:
# 2

# %%
#建立一个一维矩阵b, b.shape 为矩阵的长度
y_train.shape
# Out:
# (10,)

# %%
y_train.shape[0]
# Out:
# 10

# %% [markdown]
# #绘制数据集及要预测的点

# %%
plt.scatter(X_train[y_train==0,0],X_train[y_train==0,1],color='g')
plt.scatter(X_train[y_train==1,0],X_train[y_train==1,1],color='b')
plt.scatter(X_train[y_train==2,0],X_train[y_train==2,1],color='r')
plt.scatter(x[0],x[1])

# %% [markdown]
# # KNN 实现过程简单编码

# %%
from math import sqrt
distance=[]
for x_train in X_train:
    d=sqrt(np.sum(x_train-x)**2)
    distance.append(d)
distance
# Out:
# [5.734532240000001,
#  7.5677257110000005,
#  6.747169047,
#  3.1978656800000005,
#  6.31198613,
#  0.6606209850000004,
#  2.1802970320000004,
#  0.2239308349999991,
#  0.24246641000000047,
#  2.727880784]

# %%
# 返回排序后的结果的索引,也就是距离测试点距离最近的点的排序坐标数组
nearset=np.argsort(distance)

# %%
nearset
# Out:
# array([7, 8, 5, 6, 9, 3, 0, 4, 2, 1], dtype=int64)

# %%
k=6

# %%
#投票选择
nearset[:6]
# Out:
# array([7, 8, 5, 6, 9, 3], dtype=int64)

# %%
topk_y=[y_train[i] for i in nearset[:6]]
topk_y
# Out:
# [1, 1, 1, 1, 2, 0]

# %%
topk_y.count(1)
# Out:
# 4

# %%
## collections的Counter方法可以求出一个数组的相同元素的个数，返回一个dict【key=元素名，value=元素个数】
from collections import Counter
Counter(topk_y)
# Out:
# Counter({1: 4, 2: 1, 0: 1})

# %%
Counter(topk_y)[0]
# Out:
# 1

# %%
# most_common方法求出最多的元素对应的那个键值对
votes=Counter(topk_y).most_common(1)
votes
# Out:
# [(1, 4)]

# %%
votes[0]
# Out:
# (1, 4)

# %%
#最多的类别
votes[0][0]
# Out:
# 1

# %%
#最多类别的数量
votes[0][1]
# Out:
# 4

# %% [markdown]
# # counter计数的探究

# %%
from collections import Counter

# %%
c=Counter('sadadfsdsas')
c
# Out:
# Counter({'s': 4, 'a': 3, 'd': 3, 'f': 1})

# %%
#most_common([n])对字典进行统计
c.most_common(2)
# Out:
# [('s', 4), ('a', 3)]

# %% [markdown]
# 接下来是通用用法，下面的这些Counter对象都是支持的，包括：
#
# c.values()
#
# sum(c.values())
#
# c.keys()
#
# c.clear()
#
# list(c)
#
# set(c)
#
# dict(c)
#
# c.items()
#
# c += Counter()    #这个是最神奇的，就是可以将负数和0的值对应的key项去掉

# %%
c.values()
# Out:
# dict_values([4, 3, 3, 1])

# %%
sum(c.values())
# Out:
# 11

# %%
c.keys()
# Out:
# dict_keys(['s', 'a', 'd', 'f'])

# %%
c.keys()
# Out:
# dict_keys(['s', 'a', 'd', 'f'])

# %%
c.items()
# Out:
# dict_items([('s', 4), ('a', 3), ('d', 3), ('f', 1)])

# %%
#变成字典
dict(c)
# Out:
# {'s': 4, 'a': 3, 'd': 3, 'f': 1}

# %%
c.most_common()
# Out:
# [('s', 4), ('a', 3), ('d', 3), ('f', 1)]

# %%
#
c.values()
# Out:
# dict_values([4, 3, 3, 1])

# %% [markdown]
# # KNN算法的封装

# %%
import numpy as np
from math import sqrt
from collections import Counter

# %% [markdown]
# class KNNclassifier:
#     def __init__(self,k):
#         self.k=k
#         self.x=None
#         self.y=None
#     def fit(self,x_train,y_train):
#         """根据训练数据集X_train和y_train训练kNN分类器"""
#         assert x_train.shape[0]==y_train.shape[0]
#         assert self.k<=x_train.shape[0]
#         self.x=x_train
#         self.y=y_train
#         return self
#     def pre(self,x_predict):
#         ypredict=[self.predict(x) for x in x_predict]
#         return ypredict
#
#     def predict(self,x):
#         distance=[sqrt(np.sum(x_train-x)**2) for x_train in self.x]
#         nearset=np.argsort(distances)
#         topk_y=[self.y[i] for i in nearset[:self.k]]
#         votes=Counter(topk_y)
#         return votes.most_common(1)[0][0]

# %%
import numpy as np
from math import sqrt
from collections import Counter
class KNNClassifier:

    def __init__(self,k):
        """初始化kNN分类器"""
        assert k >= 1, "k must be valid"
        self.k = k
        self._X_train = None
        self._y_train = None

    def fit(self, X_train, y_train):
        """根据训练数据集X_train和y_train训练kNN分类器"""
        assert X_train.shape[0] == y_train.shape[0], \
            "the size of X_train must equal to the size of y_train"
        assert self.k <= X_train.shape[0], \
            "the size of X_train must be at least k."

        self._X_train = X_train
        self._y_train = y_train
        return self

    def predict(self, X_predict):
        """给定待预测数据集X_predict，返回标示X_predict的结果向量"""
        assert self._X_train is not None and self._y_train is not None, \
            "mush fit before predict"
        assert self._X_train.shape[1] == X_predict.shape[1], \
            "the feature number of x must be equal to X_train"

        y_predict = [self._predict(x) for x in X_predict]
        return np.array(y_predict)

    def _predict(self, x):
        """给定单个待预测数据x，返回x的预测结果值"""
        distances = [sqrt(np.sum((x_train-x)**2)) for x_train in self._X_train]
        nearset = np.argsort(distances)
        topK_y = [self._y_train[i] for i in nearset[:self.k]]
        votes = Counter(topK_y)
        return votes.most_common(1)[0][0]

# %%
raw_data_x=[
             [3.393533211,2.331273381],
             [2.110073483,1.781539638],
             [1.343808831,3.368360954],
             [3.582294042,4.679179110],
             [2.280362439,2.866990263],
             [7.423436942,4.696522875],
             [5.745051997,3.533989803],
             [9.172168622,2.511101045],
             [7.792783481,3.424088941],
             [7.939820817,0.791637231]
]
#所属类别
raw_data_y = [0,0,0,0,0,1,1,1,1,2]

# %%
#训练集合 将列表转换成数组
X_train=np.array(raw_data_x)
y_train=np.array(raw_data_y)

#要预测的点
x = np.array([8.093607318,3.365731514])

# %%
t= KNNClassifier(k=1)
t.fit(X_train,y_train)
t.predict(x)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-155-bc57a6516143> in <module>()
#       1 t= KNNClassifier(k=1)
#       2 t.fit(X_train,y_train)
# ----> 3 t.predict(x)
#
# <ipython-input-152-708577fb2beb> in predict(self, X_predict)
#      23         """给定待预测数据集X_predict，返回标示X_predict的结果向量"""
#      24         assert self._X_train is not None and self._y_train is not None,             "mush fit before predict"
# ---> 25         assert self._X_train.shape[0] == X_predict.shape[0],             "the feature number of x must be equal to X_train"
#      26
#      27         y_predict = [self._predict(x) for x in X_predict]
#
# AssertionError: the feature number of x must be equal to X_train

# %%
#准确率
sum(y_predict==y_test)/len(y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-156-ff6cd68c2a86> in <module>()
#       1 #准确率
# ----> 2 sum(y_predict==y_test)/len(y_test)
#
# NameError: name 'y_predict' is not defined
